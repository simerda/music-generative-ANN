# %%
# !pip install --upgrade -q mido

# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

import time
import glob
import os
import pickle

from enum import IntEnum
from collections import deque

from torch.utils.data import Dataset, DataLoader
from mido import MidiFile, MidiTrack, Message, MetaMessage

# %%
# !nvidia-smi
# Out:
# Thu May 12 10:28:26 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    23W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
MAX_TOKENS = 4096

# %%
# import serializer definition
# %run /content/gdrive/MyDrive/Colab\ Notebooks/serializer-single.ipynb

# %%
class MaestroDataset(Dataset):

    def __init__(self, ds_path: str, device: str):
        self.ds_path = ds_path
        self.length = len(glob.glob(os.path.join(self.ds_path, "*.pt")))
        self.device = device


    def __len__(self):
        return self.length

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        if isinstance(idx, int):
          idx = [idx]

        tensors = []
        for i in idx:
          ts_path = os.path.join(self.ds_path, str(i) + ".pt")
          tsor = torch.load(ts_path, map_location=self.device)[:MAX_TOKENS+1]
          if tsor[-1] != SpecialTokens.PADDING.value:
            tsor[-1] = SpecialTokens.END.value
          tensors.append(tsor)

        return torch.cat(tensors)

# %%
DS_TYPE = "single" # chord or single representation
DS_PATH = "/content/gdrive/MyDrive/BP/datasets/MAESTRO-" + DS_TYPE
BATCH_SIZE = 1
with open(os.path.join(DS_PATH, "serializer.pickle"), "rb") as f:
  serializer = pickle.load(f)
train_ds = MaestroDataset(os.path.join(DS_PATH, "train"), "cuda:0")
test_ds = MaestroDataset(os.path.join(DS_PATH, "test"), "cuda:0")
valid_ds = MaestroDataset(os.path.join(DS_PATH, "validation"), "cuda:0")

# %%
training_loader = torch.utils.data.DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=0)
test_loader = torch.utils.data.DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=0)
valid_loader = torch.utils.data.DataLoader(valid_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=0)

# %%
class TransformerModel(nn.Module):

    def __init__(self, ntoken, ninp, nhead, nhid, nlayers, dropout=0.5):
        super(TransformerModel, self).__init__()
        from torch.nn import TransformerEncoder, TransformerEncoderLayer
        self.model_type = 'Transformer'
        self.src_mask = None
        self.pos_encoder = PositionalEncoding(ninp, dropout)
        encoder_layers = TransformerEncoderLayer(ninp, nhead, nhid, dropout)
        self.transformer_encoder = TransformerEncoder(encoder_layers, nlayers)
        self.encoder = nn.Embedding(ntoken, ninp)
        self.ninp = ninp
        self.decoder = nn.Linear(ninp, ntoken)

        self.init_weights()

    def _generate_square_subsequent_mask(self, sz):
        mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
        mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
        return mask

    def init_weights(self):
        initrange = 0.1
        self.encoder.weight.data.uniform_(-initrange, initrange)
        self.decoder.bias.data.zero_()
        self.decoder.weight.data.uniform_(-initrange, initrange)

    def forward(self, src):
        if self.src_mask is None or self.src_mask.size(0) != len(src):
            device = src.device
            mask = self._generate_square_subsequent_mask(len(src)).to(device)
            self.src_mask = mask

        src = self.encoder(src) * math.sqrt(self.ninp)
        src = self.pos_encoder(src)
        output = self.transformer_encoder(src, self.src_mask)
        output = self.decoder(output)
        return output

# %%
class PositionalEncoding(nn.Module):

    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0), :]
        return self.dropout(x)

# %%
vocab_size = serializer.vocab_size() # the size of vocabulary
d_model = 512 # embedding dimension
dff = 2048 # the dimension of the feedforward network model in nn.TransformerEncoder
num_layers = 6 # the number of nn.TransformerEncoderLayer in nn.TransformerEncoder
nhead = 8 # the number of heads in the multiheadattention models
dropout = 0.1 # the dropout value
model = TransformerModel(vocab_size, d_model, nhead, dff, num_layers, dropout).to("cuda:0")

# %%
class CategoricalAccuracy(torch.nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, input: torch.Tensor, target: torch.Tensor):
        """
        :param input: [B, T, V]
        :param target: [B, T]
        :return:
        """
        input = input.softmax(-1)
        categorical_input = input.argmax(-1)
        bool_acc = categorical_input.long() == target.long()
        return bool_acc.sum().to(torch.float) / bool_acc.numel()

# %%
criterion = nn.CrossEntropyLoss()
accuracy_metric = CategoricalAccuracy()
lr = 5.0 # learning rate
optimizer = torch.optim.SGD(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1.0, gamma=0.95)

def train():
    model.train() # Turn on the train mode
    vocab_size = serializer.vocab_size()
    total_loss = 0.
    total_acc = 0.
    for batch in training_loader:
        batch_x = batch[:, :-1].contiguous()
        batch_y = batch[:, 1:].contiguous()
        optimizer.zero_grad()
        output = model(batch_x)

        loss = criterion(output.view(-1, vocab_size), batch_y.flatten())
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
        optimizer.step()

        total_loss += loss.item()
        total_acc += float(accuracy_metric(output, batch_y))

    return total_loss / len(training_loader), total_acc / len(training_loader)

def evaluate(eval_model, data_source):
    eval_model.eval() # Turn on the evaluation mode
    total_loss = 0.
    total_acc = 0.
    vocab_size = serializer.vocab_size()
    with torch.no_grad():
        for eval_batch in data_source:
            eval_x = eval_batch[:, :-1].contiguous()
            eval_y = eval_batch[:, 1:].contiguous()
            output = eval_model(eval_x)
            output_flat = output.view(-1, vocab_size)
            total_loss += criterion(output_flat, eval_y.flatten()).item()
            total_acc += float(accuracy_metric(output_flat, eval_y))

    return total_loss / len(data_source), total_acc / len(data_source)

# %%
EPOCHS = 100

# %%
epoch = -1
cumulative_epoch_time = 0

# %%
metric_log_path = '/content/gdrive/MyDrive/BP/logs/vanilla-transformer/' + DS_TYPE + '/training.csv'
time_log_path = '/content/gdrive/MyDrive/BP/logs/vanilla-transformer/' + DS_TYPE + '/time.csv'
best_test_loss = float("inf")
best_model = None
best_model_epoch = epoch

# Train Start
for _ in range(EPOCHS):
    epoch += 1
    epoch_start_time = time.time()
    train_loss, train_accuracy = train()
    test_loss, test_accuracy = evaluate(model, test_loader)
    time_elapsed = time.time() - epoch_start_time
    cumulative_epoch_time += time_elapsed
    print('-' * 112)
    print('| end of epoch {} | time: {:.2f}s | train loss {:.2f} | train accuracy {:.2f} | test loss {:.2f} | test accuracy {:.2f} |'.format(epoch+1, time_elapsed, train_loss, train_accuracy, test_loss, test_accuracy))
    print('-' * 112)

    # write csv metric information
    with open(metric_log_path, "a") as logf:
      logf.write(",".join([str(epoch+1), str(train_loss), str(train_accuracy), str(test_loss), str(test_accuracy)]) + "\n")
    
    # write learning time information
    gpu_name = torch.cuda.get_device_name(torch.device('cuda:0'))
    with open(time_log_path, "a") as logf:
      logf.write(",".join([str(epoch+1), str(cumulative_epoch_time), gpu_name]) + "\n")

    if test_loss < best_test_loss:
        best_test_loss = test_loss
        best_model = model
        best_model_epoch = epoch

    scheduler.step()
    torch.save(model.state_dict(), '/content/gdrive/MyDrive/BP/checkpoints/vanilla-transformer/' + DS_TYPE + '/epoch-{}.pth'.format(epoch))

torch.save(model.state_dict(), '/content/gdrive/MyDrive/BP/checkpoints/vanilla-transformer/' + DS_TYPE + '/epoch-{}-final.pth'.format(epoch))
torch.save(best_model.state_dict(), '/content/gdrive/MyDrive/BP/checkpoints/vanilla-transformer/' + DS_TYPE + '/best-model-epoch-{}.pth'.format(best_model_epoch))
# Out:
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 1 | time: 283.12s | train loss 4.75 | train accuracy 0.15 | test loss 3.46 | test accuracy 0.19 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 2 | time: 111.06s | train loss 3.57 | train accuracy 0.18 | test loss 3.52 | test accuracy 0.20 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 3 | time: 110.75s | train loss 3.51 | train accuracy 0.18 | test loss 3.40 | test accuracy 0.20 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 4 | time: 110.70s | train loss 3.47 | train accuracy 0.18 | test loss 3.38 | test accuracy 0.20 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 5 | time: 110.73s | train loss 3.43 | train accuracy 0.19 | test loss 3.30 | test accuracy 0.18 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 6 | time: 110.84s | train loss 3.40 | train accuracy 0.19 | test loss 3.44 | test accuracy 0.18 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 7 | time: 110.75s | train loss 3.39 | train accuracy 0.19 | test loss 3.43 | test accuracy 0.18 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 8 | time: 111.37s | train loss 3.38 | train accuracy 0.19 | test loss 3.38 | test accuracy 0.18 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 9 | time: 111.02s | train loss 3.36 | train accuracy 0.18 | test loss 3.27 | test accuracy 0.20 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 10 | time: 111.31s | train loss 3.32 | train accuracy 0.19 | test loss 3.36 | test accuracy 0.18 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 11 | time: 111.19s | train loss 3.39 | train accuracy 0.18 | test loss 3.42 | test accuracy 0.18 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 12 | time: 110.88s | train loss 3.38 | train accuracy 0.17 | test loss 3.30 | test accuracy 0.18 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 13 | time: 110.89s | train loss 3.38 | train accuracy 0.18 | test loss 3.30 | test accuracy 0.18 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 14 | time: 111.43s | train loss 3.37 | train accuracy 0.17 | test loss 3.32 | test accuracy 0.18 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 15 | time: 111.20s | train loss 3.28 | train accuracy 0.19 | test loss 3.19 | test accuracy 0.20 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 16 | time: 111.01s | train loss 3.32 | train accuracy 0.18 | test loss 3.33 | test accuracy 0.18 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 17 | time: 111.23s | train loss 3.35 | train accuracy 0.17 | test loss 3.30 | test accuracy 0.18 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 18 | time: 111.30s | train loss 3.34 | train accuracy 0.18 | test loss 3.23 | test accuracy 0.20 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 19 | time: 110.77s | train loss 3.10 | train accuracy 0.23 | test loss 2.84 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 20 | time: 111.87s | train loss 2.87 | train accuracy 0.30 | test loss 2.83 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 21 | time: 111.58s | train loss 2.86 | train accuracy 0.30 | test loss 2.83 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 22 | time: 111.42s | train loss 2.86 | train accuracy 0.30 | test loss 2.83 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 23 | time: 111.35s | train loss 2.82 | train accuracy 0.31 | test loss 2.80 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 24 | time: 110.80s | train loss 2.81 | train accuracy 0.31 | test loss 2.80 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 25 | time: 110.84s | train loss 2.86 | train accuracy 0.30 | test loss 3.08 | test accuracy 0.19 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 26 | time: 110.83s | train loss 2.88 | train accuracy 0.29 | test loss 2.80 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 27 | time: 110.81s | train loss 2.80 | train accuracy 0.31 | test loss 2.80 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 28 | time: 110.80s | train loss 2.80 | train accuracy 0.32 | test loss 2.79 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 29 | time: 110.93s | train loss 2.80 | train accuracy 0.32 | test loss 2.80 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 30 | time: 110.95s | train loss 2.80 | train accuracy 0.32 | test loss 2.81 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 31 | time: 111.33s | train loss 2.80 | train accuracy 0.32 | test loss 2.79 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 32 | time: 111.23s | train loss 2.80 | train accuracy 0.32 | test loss 2.79 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 33 | time: 111.85s | train loss 2.80 | train accuracy 0.32 | test loss 2.80 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 34 | time: 111.36s | train loss 2.79 | train accuracy 0.32 | test loss 2.79 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 35 | time: 111.50s | train loss 2.79 | train accuracy 0.32 | test loss 2.79 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 36 | time: 111.19s | train loss 2.79 | train accuracy 0.32 | test loss 2.79 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 37 | time: 111.20s | train loss 2.79 | train accuracy 0.32 | test loss 2.79 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 38 | time: 111.03s | train loss 2.79 | train accuracy 0.32 | test loss 2.79 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 39 | time: 110.81s | train loss 2.79 | train accuracy 0.32 | test loss 2.79 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 40 | time: 110.78s | train loss 2.79 | train accuracy 0.32 | test loss 2.79 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 41 | time: 110.95s | train loss 2.79 | train accuracy 0.32 | test loss 2.79 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 42 | time: 110.95s | train loss 2.79 | train accuracy 0.32 | test loss 2.79 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 43 | time: 110.67s | train loss 2.79 | train accuracy 0.32 | test loss 2.79 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 44 | time: 110.46s | train loss 2.79 | train accuracy 0.32 | test loss 2.79 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 45 | time: 109.93s | train loss 2.79 | train accuracy 0.32 | test loss 2.79 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 46 | time: 109.91s | train loss 2.79 | train accuracy 0.32 | test loss 2.79 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 47 | time: 110.68s | train loss 2.79 | train accuracy 0.32 | test loss 2.79 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 48 | time: 110.23s | train loss 2.79 | train accuracy 0.32 | test loss 2.79 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 49 | time: 111.20s | train loss 2.79 | train accuracy 0.32 | test loss 2.78 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 50 | time: 110.06s | train loss 2.79 | train accuracy 0.32 | test loss 2.79 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 51 | time: 110.69s | train loss 2.79 | train accuracy 0.32 | test loss 2.79 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 52 | time: 109.95s | train loss 2.79 | train accuracy 0.32 | test loss 2.79 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 53 | time: 110.11s | train loss 2.79 | train accuracy 0.32 | test loss 2.79 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 54 | time: 110.04s | train loss 2.79 | train accuracy 0.32 | test loss 2.78 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 55 | time: 110.05s | train loss 2.79 | train accuracy 0.32 | test loss 2.79 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 56 | time: 109.89s | train loss 2.79 | train accuracy 0.32 | test loss 2.79 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 57 | time: 110.43s | train loss 2.79 | train accuracy 0.32 | test loss 2.79 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 58 | time: 111.10s | train loss 2.79 | train accuracy 0.32 | test loss 2.78 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 59 | time: 111.71s | train loss 2.79 | train accuracy 0.32 | test loss 2.79 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 60 | time: 111.27s | train loss 2.79 | train accuracy 0.32 | test loss 2.78 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 61 | time: 110.41s | train loss 2.79 | train accuracy 0.32 | test loss 2.79 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 62 | time: 111.06s | train loss 2.79 | train accuracy 0.32 | test loss 2.78 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 63 | time: 112.53s | train loss 2.79 | train accuracy 0.32 | test loss 2.78 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 64 | time: 110.51s | train loss 2.79 | train accuracy 0.32 | test loss 2.79 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 65 | time: 112.00s | train loss 2.79 | train accuracy 0.32 | test loss 2.78 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 66 | time: 112.36s | train loss 2.79 | train accuracy 0.32 | test loss 2.79 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 67 | time: 112.62s | train loss 2.79 | train accuracy 0.32 | test loss 2.79 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 68 | time: 112.73s | train loss 2.79 | train accuracy 0.32 | test loss 2.78 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 69 | time: 112.53s | train loss 2.79 | train accuracy 0.32 | test loss 2.78 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 70 | time: 112.84s | train loss 2.79 | train accuracy 0.32 | test loss 2.78 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 71 | time: 112.64s | train loss 2.79 | train accuracy 0.32 | test loss 2.78 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 72 | time: 112.59s | train loss 2.79 | train accuracy 0.32 | test loss 2.78 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 73 | time: 112.62s | train loss 2.79 | train accuracy 0.32 | test loss 2.79 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 74 | time: 112.55s | train loss 2.79 | train accuracy 0.32 | test loss 2.79 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 75 | time: 112.55s | train loss 2.79 | train accuracy 0.32 | test loss 2.78 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 76 | time: 112.60s | train loss 2.78 | train accuracy 0.32 | test loss 2.79 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 77 | time: 112.52s | train loss 2.78 | train accuracy 0.32 | test loss 2.78 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 78 | time: 112.56s | train loss 2.78 | train accuracy 0.32 | test loss 2.78 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 79 | time: 112.31s | train loss 2.78 | train accuracy 0.32 | test loss 2.78 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 80 | time: 112.50s | train loss 2.78 | train accuracy 0.32 | test loss 2.79 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 81 | time: 112.61s | train loss 2.78 | train accuracy 0.32 | test loss 2.79 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 82 | time: 112.85s | train loss 2.78 | train accuracy 0.32 | test loss 2.78 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 83 | time: 112.76s | train loss 2.78 | train accuracy 0.32 | test loss 2.78 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 84 | time: 112.58s | train loss 2.78 | train accuracy 0.32 | test loss 2.78 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 85 | time: 112.87s | train loss 2.78 | train accuracy 0.32 | test loss 2.78 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 86 | time: 112.65s | train loss 2.78 | train accuracy 0.32 | test loss 2.78 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 87 | time: 112.57s | train loss 2.78 | train accuracy 0.32 | test loss 2.78 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 88 | time: 112.99s | train loss 2.78 | train accuracy 0.32 | test loss 2.78 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 89 | time: 112.82s | train loss 2.78 | train accuracy 0.32 | test loss 2.78 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 90 | time: 112.65s | train loss 2.78 | train accuracy 0.32 | test loss 2.78 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 91 | time: 112.70s | train loss 2.78 | train accuracy 0.32 | test loss 2.78 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 92 | time: 112.71s | train loss 2.78 | train accuracy 0.32 | test loss 2.78 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 93 | time: 112.55s | train loss 2.78 | train accuracy 0.32 | test loss 2.78 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 94 | time: 112.58s | train loss 2.78 | train accuracy 0.32 | test loss 2.78 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 95 | time: 112.69s | train loss 2.78 | train accuracy 0.32 | test loss 2.78 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 96 | time: 112.77s | train loss 2.78 | train accuracy 0.32 | test loss 2.78 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 97 | time: 112.92s | train loss 2.78 | train accuracy 0.32 | test loss 2.78 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 98 | time: 113.62s | train loss 2.78 | train accuracy 0.32 | test loss 2.78 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 99 | time: 113.18s | train loss 2.78 | train accuracy 0.32 | test loss 2.78 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 100 | time: 112.94s | train loss 2.78 | train accuracy 0.32 | test loss 2.78 | test accuracy 0.32 |
# ----------------------------------------------------------------------------------------------------------------

# %%
def generate(model, primer=None, length=MAX_TOKENS):
  model.eval()
  inputs = primer
  if inputs is None:
    inputs = [SpecialTokens.START.value]
  
  for _ in range(length - len(inputs) + 1):
    np_arr = np.array([inputs])
    tensor_inp = torch.from_numpy(np_arr).to("cuda:0")
    
    result = model(tensor_inp)[0, -1]
    token = int(result.softmax(-1).argmax(-1))

    if token == SpecialTokens.END.value:
      break
    
    inputs.append(token)
  inputs.append(SpecialTokens.END.value)
  return inputs

# %%
generated = generate(best_model)
deserialized = serializer.deserialize(generated)
deserialized.save("/content/generated.midi")
