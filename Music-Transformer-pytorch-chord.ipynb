# %%
# get the music transformer implementation
# !git clone https://github.com/jason9693/MusicTransformer-pytorch.git music_transformer
# !cp -a ./music_transformer/. ./


# install dependencies
# !pip install --upgrade -q mido fairseq transformers pretty-midi tensorboardX progress
# !pip install -r requirements.txt

# fetch the dataset
# !wget https://storage.googleapis.com/magentadata/datasets/maestro/v3.0.0/maestro-v3.0.0.json
# Out:
# Cloning into 'music_transformer'...
# remote: Enumerating objects: 217, done.
# remote: Counting objects: 100% (66/66), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 217 (delta 49), reused 40 (delta 40), pack-reused 151
# Receiving objects: 100% (217/217), 491.55 KiB | 12.94 MiB/s, done.
# Resolving deltas: 100% (117/117), done.
#      |████████████████████████████████| 51 kB 5.4 MB/s
#      |████████████████████████████████| 1.7 MB 28.6 MB/s
#      |████████████████████████████████| 4.0 MB 49.0 MB/s
#      |████████████████████████████████| 5.6 MB 22.6 MB/s
#      |████████████████████████████████| 125 kB 54.3 MB/s
#      |████████████████████████████████| 90 kB 5.8 MB/s
#      |████████████████████████████████| 147 kB 45.9 MB/s
#      |████████████████████████████████| 84 kB 3.2 MB/s
#      |████████████████████████████████| 596 kB 52.4 MB/s
#      |████████████████████████████████| 880 kB 51.9 MB/s
#      |████████████████████████████████| 6.6 MB 36.8 MB/s
#      |████████████████████████████████| 112 kB 4.6 MB/s
#      |████████████████████████████████| 74 kB 4.0 MB/s
#   Building wheel for pretty-midi (setup.py) ... done
#   Building wheel for progress (setup.py) ... done
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Building wheel for sacremoses (setup.py) ... done
# Requirement already satisfied: tensorboardX in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 1)) (2.5)
# Collecting jsonpath-ng==1.4.3
#   Downloading jsonpath_ng-1.4.3-py2.py3-none-any.whl (29 kB)
# Collecting Mako==1.0.12
#   Downloading Mako-1.0.12.tar.gz (460 kB)
#      |████████████████████████████████| 460 kB 20.3 MB/s
# Collecting Markdown==3.1.1
#   Downloading Markdown-3.1.1-py2.py3-none-any.whl (87 kB)
#      |████████████████████████████████| 87 kB 8.2 MB/s
# Collecting MarkupSafe==1.1.1
#   Downloading MarkupSafe-1.1.1-cp37-cp37m-manylinux2010_x86_64.whl (33 kB)
# Collecting mlflow==1.0.0
#   Downloading mlflow-1.0.0-py3-none-any.whl (47.7 MB)
#      |████████████████████████████████| 47.7 MB 1.9 MB/s
# Collecting nanotime==0.5.2
#   Downloading nanotime-0.5.2.tar.gz (3.2 kB)
# Collecting networkx==2.3
#   Downloading networkx-2.3.zip (1.7 MB)
#      |████████████████████████████████| 1.7 MB 55.6 MB/s
# Collecting numpy==1.16.4
#   Downloading numpy-1.16.4-cp37-cp37m-manylinux1_x86_64.whl (17.3 MB)
#      |████████████████████████████████| 17.3 MB 48.5 MB/s
# Collecting pathspec==0.5.9
#   Downloading pathspec-0.5.9.tar.gz (25 kB)
# Collecting pbr==5.3.1
#   Downloading pbr-5.3.1-py2.py3-none-any.whl (108 kB)
#      |████████████████████████████████| 108 kB 64.2 MB/s
# Collecting Pillow==6.2.0
#   Downloading Pillow-6.2.0-cp37-cp37m-manylinux1_x86_64.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 49.8 MB/s
# Collecting ply==3.11
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 5.3 MB/s
# Collecting pretty-midi==0.2.8
#   Downloading pretty_midi-0.2.8.tar.gz (5.6 MB)
#      |████████████████████████████████| 5.6 MB 35.5 MB/s
# Collecting progress==1.5
#   Downloading progress-1.5.tar.gz (5.8 kB)
# Collecting protobuf==3.8.0
#   Downloading protobuf-3.8.0-cp37-cp37m-manylinux1_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 51.4 MB/s
# Collecting psutil==5.6.2
#   Downloading psutil-5.6.2.tar.gz (432 kB)
#      |████████████████████████████████| 432 kB 68.2 MB/s
# Collecting pyasn1==0.4.5
#   Downloading pyasn1-0.4.5-py2.py3-none-any.whl (73 kB)
#      |████████████████████████████████| 73 kB 2.7 MB/s
# Collecting pycrypto==2.6.1
#   Downloading pycrypto-2.6.1.tar.gz (446 kB)
#      |████████████████████████████████| 446 kB 72.2 MB/s
# Collecting pyfiglet==0.8.post1
#   Downloading pyfiglet-0.8.post1-py2.py3-none-any.whl (865 kB)
#      |████████████████████████████████| 865 kB 56.4 MB/s
# Requirement already satisfied: pygobject==3.26.1 in /usr/lib/python3/dist-packages (from -r requirements.txt (line 21)) (3.26.1)
# ERROR: Could not find a version that satisfies the requirement python-apt==1.6.4 (from versions: 0.0.0, 0.7.8)
# ERROR: No matching distribution found for python-apt==1.6.4
# --2022-05-12 10:52:34--  https://storage.googleapis.com/magentadata/datasets/maestro/v3.0.0/maestro-v3.0.0.json
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.251.18.128, 142.250.153.128, 142.250.145.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.251.18.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 369237 (361K) [application/octet-stream]
# Saving to: ‘maestro-v3.0.0.json’
#
# maestro-v3.0.0.json 100%[===================>] 360.58K  --.-KB/s    in 0.003s
#
# 2022-05-12 10:52:34 (114 MB/s) - ‘maestro-v3.0.0.json’ saved [369237/369237]

# %%
# !nvidia-smi
# Out:
# Thu May 12 10:52:35 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    23W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from music_transformer.model import MusicTransformer
import custom
from custom.metrics import *
from custom.criterion import SmoothCrossEntropyLoss, CustomSchedule
from custom.config import config
from data import Data
from mido import MidiFile, MidiTrack, Message, MetaMessage

import utils
import datetime
import time
import json
import pickle
import glob
import os

from enum import IntEnum
from os import path
from collections import deque

import torch
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
BASE_PATH = "/content"
DATASET_PATH = "maestro-v3.0.0"

with open("maestro-v3.0.0.json", "r") as index:
  index_js = json.load(index)

def get_path(index: int) -> str:
  return path.join(BASE_PATH, DATASET_PATH, index_js["midi_filename"][str(index)])

# %%
# import serializer definition
# %run /content/gdrive/MyDrive/Colab\ Notebooks/serializer-chord.ipynb

# %%
MAX_TOKENS = 512

# %%
class MaestroDataset(Dataset):

    def __init__(self, ds_path: str, device: str):
        self.ds_path = ds_path
        self.length = len(glob.glob(path.join(self.ds_path, "*.pt")))
        self.device = device


    def __len__(self):
        return self.length

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        if isinstance(idx, int):
          idx = [idx]

        tensors = []
        for i in idx:
          ts_path = os.path.join(self.ds_path, str(i) + ".pt")
          tsor = torch.load(ts_path, map_location=self.device)[:MAX_TOKENS+1]
          if tsor[-1] != SpecialTokens.PADDING.value:
            tsor[-1] = SpecialTokens.END.value
          tensors.append(tsor)

        return torch.cat(tensors)

# %%
DS_TYPE = "chord" # chord or single
DS_PATH = "/content/gdrive/MyDrive/BP/datasets/MAESTRO-" + DS_TYPE
BATCH_SIZE = 1
with open(path.join(DS_PATH, "serializer.pickle"), "rb") as f:
  serializer = pickle.load(f)
train_ds = MaestroDataset(path.join(DS_PATH, "train"), "cuda:0")
test_ds = MaestroDataset(path.join(DS_PATH, "test"), "cuda:0")
valid_ds = MaestroDataset(path.join(DS_PATH, "validation"), "cuda:0")

# %%
training_loader = torch.utils.data.DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=0)
test_loader = torch.utils.data.DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=0)
valid_loader = torch.utils.data.DataLoader(valid_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=0)

# %%
# load model
device = 'cuda:0'

EMBEDDING_DIM = 256
LABEL_SMOOTH = 0.1

DEBUG = 'true'
config.pad_token = SpecialTokens.PADDING.value
# define model
model = MusicTransformer(
            embedding_dim=EMBEDDING_DIM,
            vocab_size=serializer.vocab_size(),
            num_layer=6,
            max_seq=MAX_TOKENS,
            dropout=0.1,
            debug=DEBUG,
            loader_path=None
)
model.to(device)
opt = optim.Adam(model.parameters(), lr=0, betas=(0.9, 0.98), eps=1e-9)
scheduler = CustomSchedule(EMBEDDING_DIM, optimizer=opt)


# init train metric set
metric_set = MetricsSet({
    'accuracy': CategoricalAccuracy(),
    'loss': SmoothCrossEntropyLoss(LABEL_SMOOTH, serializer.vocab_size(), SpecialTokens.PADDING.value)
})

# %%
EPOCHS = 100

# %%
epoch = -1
cumulative_epoch_time = 0

# %%
def train():
    model.train()
    total_loss = 0.
    total_acc = 0.

    for batch in training_loader:
        batch_x = batch[:, :-1].contiguous()
        batch_y = batch[:, 1:].contiguous()
        scheduler.optimizer.zero_grad()
        sample = model.forward(batch_x)

        metrics = metric_set(sample, batch_y)
        loss = metrics['loss']
        loss.backward()
        scheduler.step()

        total_acc += float(metrics['accuracy'])
        total_loss += loss.item()

    return total_loss / len(training_loader), total_acc / len(training_loader)


def evaluate(eval_model, data_source):
    eval_model.test() # Turn on the evaluation mode
    eval_model.infer = False
    total_loss = 0.
    total_acc = 0.
    vocab_size = serializer.vocab_size()
    with torch.no_grad():
        for eval_batch in data_source:
            eval_x = eval_batch[:, :-1].contiguous()
            eval_y = eval_batch[:, 1:].contiguous()
            output = eval_model.forward(eval_x)[0]

            metrics = metric_set(output, eval_y)
            total_loss += metrics['loss'].item()
            total_acc += float(metrics['accuracy'])

    return total_loss / len(data_source), total_acc / len(data_source)

# %%
metric_log_path = '/content/gdrive/MyDrive/BP/logs/music-transformer/' + DS_TYPE + '/training.csv'
time_log_path = '/content/gdrive/MyDrive/BP/logs/music-transformer/' + DS_TYPE + '/time.csv'
best_test_loss = float("inf")
best_model = None
best_model_epoch = epoch

# Train Start
for _ in range(EPOCHS):
    epoch += 1
    epoch_start_time = time.time()
    train_loss, train_accuracy = train()
    test_loss, test_accuracy = evaluate(model, test_loader)
    time_elapsed = time.time() - epoch_start_time
    cumulative_epoch_time += time_elapsed
    print('-' * 112)
    print('| end of epoch {} | time: {:.2f}s | train loss {:.2f} | train accuracy {:.2f} | test loss {:.2f} | test accuracy {:.2f} |'.format(epoch+1, time_elapsed, train_loss, train_accuracy, test_loss, test_accuracy))
    print('-' * 112)

    # write csv metric information
    with open(metric_log_path, "a") as logf:
      logf.write(",".join([str(epoch+1), str(train_loss), str(train_accuracy), str(test_loss), str(test_accuracy)]) + "\n")
    
    # write learning time information
    gpu_name = torch.cuda.get_device_name(torch.device('cuda:0'))
    with open(time_log_path, "a") as logf:
      logf.write(",".join([str(epoch+1), str(cumulative_epoch_time), gpu_name]) + "\n")


    if test_loss < best_test_loss:
        best_test_loss = test_loss
        best_model = model
        best_model_epoch = epoch

    scheduler.step()
    torch.save(model.state_dict(), '/content/gdrive/MyDrive/BP/checkpoints/music-transformer/' + DS_TYPE + '/epoch-{}.pth'.format(epoch))

torch.save(model.state_dict(), '/content/gdrive/MyDrive/BP/checkpoints/music-transformer/' + DS_TYPE + '/epoch-{}-final.pth'.format(epoch))
torch.save(best_model.state_dict(), '/content/gdrive/MyDrive/BP/checkpoints/music-transformer/' + DS_TYPE + '/best-model-epoch-{}.pth'.format(best_model_epoch))
# Out:
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 51 | time: 307.83s | train loss 4.10 | train accuracy 0.40 | test loss 5.08 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 52 | time: 305.10s | train loss 4.09 | train accuracy 0.40 | test loss 5.06 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 53 | time: 304.85s | train loss 4.09 | train accuracy 0.40 | test loss 5.07 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 54 | time: 304.96s | train loss 4.08 | train accuracy 0.40 | test loss 5.05 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 55 | time: 304.81s | train loss 4.07 | train accuracy 0.40 | test loss 5.07 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 56 | time: 305.24s | train loss 4.07 | train accuracy 0.40 | test loss 5.06 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 57 | time: 305.10s | train loss 4.07 | train accuracy 0.40 | test loss 5.07 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 58 | time: 305.15s | train loss 4.06 | train accuracy 0.40 | test loss 5.06 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 59 | time: 304.94s | train loss 4.05 | train accuracy 0.40 | test loss 5.06 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 60 | time: 305.05s | train loss 4.05 | train accuracy 0.41 | test loss 5.06 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 61 | time: 305.25s | train loss 4.04 | train accuracy 0.41 | test loss 5.07 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 62 | time: 305.27s | train loss 4.04 | train accuracy 0.41 | test loss 5.07 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 63 | time: 305.03s | train loss 4.03 | train accuracy 0.41 | test loss 5.07 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 64 | time: 304.90s | train loss 4.03 | train accuracy 0.41 | test loss 5.06 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 65 | time: 304.70s | train loss 4.03 | train accuracy 0.41 | test loss 5.07 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 66 | time: 304.45s | train loss 4.02 | train accuracy 0.41 | test loss 5.08 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 67 | time: 304.24s | train loss 4.02 | train accuracy 0.41 | test loss 5.07 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 68 | time: 304.71s | train loss 4.02 | train accuracy 0.41 | test loss 5.08 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 69 | time: 304.78s | train loss 4.01 | train accuracy 0.41 | test loss 5.07 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 70 | time: 304.26s | train loss 4.01 | train accuracy 0.41 | test loss 5.09 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 71 | time: 304.24s | train loss 4.00 | train accuracy 0.42 | test loss 5.08 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 72 | time: 304.28s | train loss 3.99 | train accuracy 0.42 | test loss 5.08 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 73 | time: 304.28s | train loss 3.99 | train accuracy 0.42 | test loss 5.07 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 74 | time: 304.32s | train loss 3.99 | train accuracy 0.42 | test loss 5.08 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 75 | time: 304.34s | train loss 3.99 | train accuracy 0.42 | test loss 5.08 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 76 | time: 304.59s | train loss 3.98 | train accuracy 0.42 | test loss 5.08 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 77 | time: 304.40s | train loss 3.98 | train accuracy 0.42 | test loss 5.09 | test accuracy 0.30 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 78 | time: 304.25s | train loss 3.98 | train accuracy 0.42 | test loss 5.08 | test accuracy 0.30 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 79 | time: 304.37s | train loss 3.98 | train accuracy 0.42 | test loss 5.08 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 80 | time: 304.01s | train loss 3.97 | train accuracy 0.42 | test loss 5.09 | test accuracy 0.30 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 81 | time: 304.99s | train loss 3.97 | train accuracy 0.42 | test loss 5.09 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 82 | time: 304.59s | train loss 3.97 | train accuracy 0.42 | test loss 5.11 | test accuracy 0.30 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 83 | time: 304.70s | train loss 3.96 | train accuracy 0.43 | test loss 5.09 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 84 | time: 304.62s | train loss 3.96 | train accuracy 0.43 | test loss 5.10 | test accuracy 0.30 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 85 | time: 304.46s | train loss 3.96 | train accuracy 0.43 | test loss 5.10 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 86 | time: 305.01s | train loss 3.96 | train accuracy 0.43 | test loss 5.10 | test accuracy 0.30 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 87 | time: 304.97s | train loss 3.96 | train accuracy 0.43 | test loss 5.11 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 88 | time: 305.46s | train loss 3.95 | train accuracy 0.43 | test loss 5.10 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 89 | time: 304.69s | train loss 3.95 | train accuracy 0.43 | test loss 5.11 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 90 | time: 304.67s | train loss 3.95 | train accuracy 0.43 | test loss 5.11 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 91 | time: 304.55s | train loss 3.95 | train accuracy 0.43 | test loss 5.12 | test accuracy 0.30 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 92 | time: 304.81s | train loss 3.94 | train accuracy 0.43 | test loss 5.11 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 93 | time: 304.74s | train loss 3.94 | train accuracy 0.43 | test loss 5.11 | test accuracy 0.30 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 94 | time: 304.78s | train loss 3.94 | train accuracy 0.43 | test loss 5.11 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 95 | time: 304.77s | train loss 3.94 | train accuracy 0.43 | test loss 5.11 | test accuracy 0.30 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 96 | time: 304.66s | train loss 3.93 | train accuracy 0.43 | test loss 5.11 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 97 | time: 304.92s | train loss 3.93 | train accuracy 0.44 | test loss 5.12 | test accuracy 0.31 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 98 | time: 304.76s | train loss 3.92 | train accuracy 0.44 | test loss 5.12 | test accuracy 0.30 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 99 | time: 304.93s | train loss 3.92 | train accuracy 0.44 | test loss 5.12 | test accuracy 0.30 |
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# | end of epoch 100 | time: 304.66s | train loss 3.92 | train accuracy 0.44 | test loss 5.12 | test accuracy 0.30 |
# ----------------------------------------------------------------------------------------------------------------

# %%
# fetch the dataset
# !wget https://storage.googleapis.com/magentadata/datasets/maestro/v3.0.0/maestro-v3.0.0-midi.zip
# !unzip -q maestro-v3.0.0-midi.zip
# Out:
# --2022-05-11 13:54:47--  https://storage.googleapis.com/magentadata/datasets/maestro/v3.0.0/maestro-v3.0.0-midi.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.251.31.128, 142.251.18.128, 142.250.153.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.251.31.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58416533 (56M) [application/octet-stream]
# Saving to: ‘maestro-v3.0.0-midi.zip’
#
# maestro-v3.0.0-midi 100%[===================>]  55.71M  32.0MB/s    in 1.7s
#
# 2022-05-11 13:54:51 (32.0 MB/s) - ‘maestro-v3.0.0-midi.zip’ saved [58416533/58416533]

# %%
# run inference
import numpy as np
config.threshold_len = 500 # deprecated value, that is required by model but not used

best_model.test()
inputs = np.array([[SpecialTokens.START.value]])
inputs = torch.from_numpy(inputs).to(device)
result = best_model(inputs, MAX_TOKENS)
# Out:
# CONFIG_FILE_NAME = save.yml
# pad_token = 0
# threshold_len = 500
# 512

# %%
generated = serializer.deserialize(result)
generated.save('/content/generated.midi')
